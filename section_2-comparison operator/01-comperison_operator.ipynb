# %%
# equality
2==2
# Out:
# True

# %%
"hello" == 'Hello'
# Out:
# False

# %%
2 == '2'
# Out:
# False

# %%
'bye' == "bye"
# Out:
# True

# %%
22.0 == 22
# Out:
# True

# %%
#inequality
2!=2
# Out:
# False

# %%
3 != 3
# Out:
# False

# %%
4 != 5
# Out:
# True

# %%
#greater than
1>2
# Out:
# False

# %%
#lesser than
2<1
# Out:
# False

# %%
2>1
# Out:
# True

# %%
# greater than equals to
2 >= 3
# Out:
# False

# %%
2 >= 2
# Out:
# True

# %%
2 >= 1
# Out:
# True

# %%
# less than equals to
2 <= 1
# Out:
# False
