# %%
2 ==2
# Out:
# True

# %%
'hello' == "Hello"
# Out:
# False

# %%
3>1 and 1<2
# Out:
# True

# %%
3>1 and 1>2
# Out:
# False

# %%
3>1 or 1<2
# Out:
# True

# %%
not 1==1
# Out:
# False

# %%
not True
# Out:
# False

# %%
2 >3 and 3<4
# Out:
# False

# %%
2 >3 and 3<4
# Out:
# False

# %%
2 >3 or 3<4
# Out:
# True

# %%
not(2 >3 and 3<4)
# Out:
# True

# %%
4>3
# Out:
# True

# %%
3<3
# Out:
# False
