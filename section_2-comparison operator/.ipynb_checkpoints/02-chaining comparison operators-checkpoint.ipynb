# %% [markdown]
# ### logical operator

# %%
1 < 2< 3
# Out:
# True

# %%
1 <2 >3
# Out:
# False

# %%
1 <2 and 2>3
# Out:
# False

# %% [markdown]
# ### and
# ### or
# ### not

# %%
# both conditions are true
(1<2) and (3>4)
# Out:
# False

# %%
'h'=='h' and 2==2
# Out:
# True

# %%
#one of then is true
1 == 2 or 2 ==2
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
# return opposite boolean value
not(1==1)
# Out:
# False

# %%
not 500<3.14
# Out:
# True

# %%
50 != 3.14
# Out:
# True

# %%
##
