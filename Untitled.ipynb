# %%
sum((1,2,3,4,5,6))
# Out:
# 21

# %%
def myfunc(*args):
    return args

# %%
myfunc(1,2,3,4,5,6)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
"String".lower()
# Out:
# 'string'

# %%
def myfunc(a):
    return "".join([ch.lower() if i%2==0 else ch.upper() for i,ch in enumerate(a)])

# %%
myfunc("Hellowolddsfrgr")
# Out:
# 'hElLoWoLdDsFrGr'

# %%
my = [.join(ch.lower) if i%2==0 else .join(ch.upper()) for i,ch in enumerate("dgienfknjkrfnnerjknfjknerr")]
# Out:
#   Cell In[49], line 1
#     my = [.join(ch.lower) if i%2==0 else .join(ch.upper()) for i,ch in enumerate("dgienfknjkrfnnerjknfjknerr")]
#           ^
# SyntaxError: invalid syntax

# %%
lis1 = 
" ".join(lis1)
# Out:
# 'h e l l o   g o o d   m o r n i n g   a n d   h a p p y   n e w   y e a r'

# %%
chars = ['a', 'B', 'c', 'D']
char2 = ["ijijijvhvjjjbjbvvvf jblugul", "kuubh"]
result = ' '.join(char2)
print(result)
# Out:
# ijijijvhvjjjbjbvvvf jblugul kuubh

# %%
result = "".join(str(n) for n in [1,2,3,4])

# %%
result
# Out:
# '1234'
