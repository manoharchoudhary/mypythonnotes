# %%
my_dog1 = 'mylow'

# %%
my_dog1
# Out:
# 'mylow'

# %% [markdown]
# ## can not use any of those symbols in variable name
#
# ### : " ' , < > ~ ! @ # & * ( ) - + - * / ^ \ | / ? . ; % ^ $

# %% [markdown]
# ###### Also avoid using builtin keyword as varibale name

# %% [markdown]
# #### Dynamic vs Statically-Typed
#
# python is Dynamically typed language meaning "you can reassign variables to different data types" eg: python

# %% [markdown]
# Statically typed languages do not support variabe reassignment to diferent data types. eg: java, C++

# %%
#ex: 
# string

x = 'marx'

# %%
#integers

x = 4

# %%
 a = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a +a
# Out:
# 20

# %%
a = a+a+a

# %%
a
# Out:
# 30

# %% [markdown]
# ### type function to know the data type

# %%
type(a)
# Out:
# int

# %%
a = 3.14

# %%
type(a)
# Out:
# float

# %%
 a = 'marx'

# %%
type(a)
# Out:
# str

# %%
type(3)
# Out:
# int

# %%
my_income = 1000
tax_rate = 0.1

my_taxes = my_income * tax_rate

# %%
my_taxes
# Out:
# 100.0
