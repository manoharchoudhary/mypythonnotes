# %%
2+1
# Out:
# 3

# %%
9/5
# Out:
# 1.8

# %%
9%5
# Out:
# 4

# %%
22/7
# Out:
# 3.142857142857143

# %%
22//7
# Out:
# 3

# %%
my_dog = "bro"

# %%
my_dog
# Out:
# 'bro'

# %%
my_dog = 4

# %%
my_dog
# Out:
# 4

# %%
type(my_dog)
# Out:
# int

# %%
print("hello \t world")
# Out:
# hello 	 world

# %%
len(my_dog)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 len(my_dog)
#
# TypeError: object of type 'int' has no len()

# %%
my_dog
# Out:
# 'bro'

# %%
"z"*10
# Out:
# 'zzzzzzzzzz'

# %%
x = "hello World"

# %%
x.capitalize()
# Out:
# 'Hello world'

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
help(x.center)
# Out:
# Help on built-in function center:
#
# center(width, fillchar=' ', /) method of builtins.str instance
#     Return a centered string of length width.
#
#     Padding is done using the specified fill character (default is a space).

# %%
x.center(width, fillchar=" ", /)
# Out:
#   Cell In[54], line 1
#     x.center(width, fillchar=" ", /)
#                                   ^
# SyntaxError: invalid syntax

# %%
x.split()
# Out:
# ['hello', 'World']

# %%
x.split('o')
# Out:
# ['hell', ' W', 'rld']

# %%
#string formatting

# %%
# .format() method

# %%
print("my name is {}".format('manohar'))
# Out:
# my name is manohar

# %%
result = 2225265/9

# %%
result
# Out:
# 247251.66666666666

# %%
print("the result is {r}".format(r=result))
# Out:
# the result is 247251.66666666666

# %%
print("the result is {r:1.3f}".format(r=result))
# Out:
# the result is 247251.667

# %%
print("the result is {r:20.3f}".format(r=result))
# Out:
# the result is           247251.667

# %%
# f-string

# %%
name = "marx"

# %%
print(f"my name is {name}")
# Out:
# my name is marx

# %%
age = 20

# %%
print(f"my name is {name} and age is {age}")
# Out:
# my name is marx and age is 20

# %%
mylist = [1,2,3,3.14,"marx"]

# %%
len(mylist)
# Out:
# 5

# %%
mylist1 = [1.618,3.14,22/7]

# %%
mylist1
# Out:
# [1.618, 3.14, 3.142857142857143]

# %%
mylist + mylist1
# Out:
# [1, 2, 3, 3.14, 'marx', 1.618, 3.14, 3.142857142857143]

# %%
mylist
# Out:
# [1, 2, 3, 3.14, 'marx']

# %%
mylist.append('abc')

# %%
mylist
# Out:
# [1, 2, 3, 3.14, 'marx', 'abc']

# %%
mylist.insert(0,'ten')

# %%
mylist
# Out:
# ['ten', 1, 2, 3, 3.14, 'marx', 'abc']

# %%
mylist.pop()
# Out:
# 'abc'

# %%
mylist
# Out:
# ['ten', 1, 2, 3, 3.14, 'marx']

# %%
mylist.pop(2)
# Out:
# 2

# %%
mylist
# Out:
# ['ten', 1, 3, 3.14, 'marx']

# %%
alp_list = ['a','e','x','b','m']
num_list = [4,5,9,7,6,3,1]

# %%
type(alp_list.sort())
# Out:
# NoneType

# %%
type(alp_list)
# Out:
# list

# %%
num_list.sort()

# %%
num_list
# Out:
# [1, 3, 4, 5, 6, 7, 9]

# %%
num_list.reverse()

# %%
num_list
# Out:
# [9, 7, 6, 5, 4, 3, 1]

# %%
sohail = [1,2,3,4,5,6]

# %%
sohail
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list = []

# %%
bool(list)
# Out:
# False

# %%
#constructing dictionaries 

my_dic = {'k1':'v1','k2':'v2','k3':'v3'}

# %%
my_dic
# Out:
# {'k1': 'v1', 'k2': 'v2', 'k3': 'v3'}

# %%
my_dic['k1']
# Out:
# 'v1'

# %%
my_dic['']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 my_dic['v1']
#
# KeyError: 'v1'

# %%
#dictionary can hold other data types as well 

dic = {'k1':123,'k2':[4,5,6],'k3':{'a':'edd','b':'banana','c':['app','web','cash']}}

# %%
lists = dic['k2']
lists
# Out:
# [4, 5, 6]

# %%
dic
# Out:
# {'k1': 123,
#  'k2': [4, 5, 6],
#  'k3': {'a': 'edd', 'b': 'banana', 'c': ['app', 'web', 'cash']}}

# %%
dic{'k3':'v1'}
# Out:
#   Cell In[21], line 1
#     dic{'k3':'v1'}
#        ^
# SyntaxError: invalid syntax

# %%
lists = dic['k2']

# %%
lists
# Out:
# [4, 5, 6]

# %%
lists.append(5)

# %%
lists
# Out:
# [4, 5, 6, 5]

# %%
dic
# Out:
# {'k1': 123,
#  'k2': [4, 5, 6, 5],
#  'k3': {'a': 'edd', 'b': 'banana', 'c': ['app', 'web', 'cash']}}

# %%
lists.append(dic['k3']['c'])

# %%
lists
# Out:
# [4, 5, 6, 5, ['app', 'web', 'cash']]

# %%
dic
# Out:
# {'k1': 123,
#  'k2': [4, 5, 6, 5, ['app', 'web', 'cash']],
#  'k3': {'a': 'edd', 'b': 'banana', 'c': ['app', 'web', 'cash']}}

# %%
d= {'k1':100,'k2':200,'k3':300}

# %%
d['k4'] = 400

# %%
d['k5'] = 5000

# %%
d
# Out:
# {'k1': 100, 'k2': 200, 'k3': 300, 'k4': 400, 'k5': 5000}

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3', 'k4', 'k5'])

# %%
d.values()
# Out:
# dict_values([100, 200, 300, 400, 5000])

# %%
d.items()
# Out:
# dict_items([('k1', 100), ('k2', 200), ('k3', 300), ('k4', 400), ('k5', 5000)])

# %%
d
# Out:
# {'k1': 100, 'k2': 200, 'k3': 300, 'k4': 400, 'k5': 5000}

# %%
#creating a tuple

tup = (1,2,3,4)

lists = [1,2,3,4,5,6]

# %%
lists[0] = 'one'

# %%
lists
# Out:
# ['one', 2, 3, 4, 5, 6]

# %%
tup[0] = 'one'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 tup[0] = 'one'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = ('a','b','a','b','a','b')

# %%
t.count('a')
# Out:
# 3

# %%
myset = set()

# %%
type(myset)
# Out:
# set

# %%
myset.add(1)

# %%
myset
# Out:
# {1}

# %%
mylist = [1,1,1,1,2,2,2,3,3,3,4]

# %%
set(mylist)
# Out:
# {1, 2, 3, 4}

# %%
mylist
# Out:
# [1, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4]

# %%
b = None

# %%
type(b)
# Out:
# NoneType

# %%
b

# %%
pwd
# Out:
# 'C:\\Users\\mylow\\Desktop\\python\\my python\\00-objects and data structure basics'

# %%
2//49
# Out:
# 0

# %%
49//2
# Out:
# 24

# %%
print("my name is {}".format("manohar"))
# Out:
# my name is manohar

# %%
print(f"my name is {name}")
# Out:
# my name is manohar

# %%
name = "manohar"

# %%
myset = set([1,2,3])

# %%
myset
# Out:
# {1, 2, 3}

# %%
type(myset)
# Out:
# set

# %%
mylist = {1,2,3,44,4,4}

# %%
mylist
# Out:
# {1, 2, 3, 4, 44}
