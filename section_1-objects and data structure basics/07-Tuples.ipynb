# %% [markdown]
# ## tuple and list are very similar , one key difference is that tuples are immutable.
# ## once a value is assigned at any particular index location unlike list it can not be reassigned.

# %%
#creating a tuple

tup = (1,2,3,4)

lists = [1,2,3,4,5,6]

# %%
lists[0] = 'ONE'

lists
# Out:
# ['ONE', 2, 3, 4, 5, 6]

# %%
# tupels are immutable
tup[0] = 'One'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # tupels are immutable
# ----> 2 tup[0] = 'One'
#
# TypeError: 'tuple' object does not support item assignment

# %%
type(tup)
# Out:
# tuple

# %%
type(lists)
# Out:
# list

# %%
len(tup)
# Out:
# 4

# %%
tup[2]
# Out:
# 3

# %%
tup[1:]
# Out:
# (2, 3, 4)

# %%
tup[0] = 'new'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 tup[0] = 'new'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# like list tuple also support mixed data type

tupl = [1,2,3,[1,2,3],"zero"]
tupl
# Out:
# [1, 2, 3, [1, 2, 3], 'zero']

# %%
t = ('a','b','a','b','a','b')

# %%
#count method in tuple

#how many time 'a' appered
t.count('a')
# Out:
# 3

# %%
t.count('b')
# Out:
# 3

# %%
lists.count(1)
# Out:
# 0

# %%
#at what index location does 'b' appered first

t.index('b')
# Out:
# 1

# %%
t.index('a')
# Out:
# 0
