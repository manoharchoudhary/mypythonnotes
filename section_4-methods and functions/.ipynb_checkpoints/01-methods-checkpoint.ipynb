# %% [markdown]
# # Methods
#
# Methods are essentially functions built into objects.
#
# Methods perform specific actions on an object and can also take arguments, just like a function.
# Methods are in the form:
#
#     object.method(arg1,arg2,etc...)

# %%
# Create a simple list

lst = [1,2,3,4,5]

# %% [markdown]
# Fortunately, with iPython and the Jupyter Notebook we can quickly see all the possible methods using the tab key. The methods for a list are:
#
# * append
# * count
# * extend
# * insert
# * pop
# * remove
# * reverse
# * sort
#
# Let's try out a few of them:

# %% [markdown]
# append() allows us to add elements to the end of a list:

# %%
lst.append(6)
lst
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
lst.pop()
# Out:
# 6

# %%
lst
# Out:
# [1, 2, 3, 4, 5]

# %%
# Check how many times 2 shows up in the list
lst.count(2)
# Out:
# 1

# %%
# removing 3 from index position 2
lst.pop(2)
# Out:
# 3

# %%
lst
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# #### help: function to get info about methods and function!

# %% [markdown]
# short hand: (shift+tab)  for help

# %%
# inserting back 3

help(lst.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
lst.insert(2,3)   #at index:-2 insert object:-3
lst
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# You can always use Shift+Tab in the Jupyter Notebook to get more help about the method. In general Python you can use the help() function:

# %%
lst.reverse()

# %%
lst
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ### in-place-method ---- changes OG list

# %% [markdown]
# for more info on methods and any topic in general refer **python official doc**

# %% [markdown]
# https://docs.python.org/3/

# %% [markdown]
# ##### Library Reference : All the Info on Classes Object and Modules in python

# %% [markdown]
# https://docs.python.org/3/library/index.html
