# %% [markdown]
# python is a simple calculator

# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*2
# Out:
# 4

# %%
4/5
# Out:
# 0.8

# %% [markdown]
# ### Modulo or "Mod" Operator

# %% [markdown]
# #### give the remender of a division

# %%
9/5
# Out:
# 1.8

# %%
9 % 5
# Out:
# 4

# %% [markdown]
# #### mod is used to check for a number is even or not

# %%
#even

50 % 2
# Out:
# 0

# %%
#odd

49 % 2
# Out:
# 1

# %% [markdown]
# #### power of numbers

# %%
#square of 10

10 ** 2
# Out:
# 100

# %%
#cude of 10

10 ** 3
# Out:
# 1000

# %%
#sq root of 100

100 ** 0.5
# Out:
# 10.0

# %%
100 ** (1/2)
# Out:
# 10.0

# %%
1000 ** (1/3)
# Out:
# 9.999999999999998

# %% [markdown]
# ### priority

# %% [markdown]
# order of operation

# %%
2+10*10+3
# Out:
# 105

# %%
# priority can be change using curley brackets

(2+10)*(10+3)
# Out:
# 156

# %%
12*13
# Out:
# 156

# %%
# special case

0.1 + 0.2 - 0.3 == 0.0
# Out:
# False

# %%
0.1 + 0.2 - 0.3
# Out:
# 5.551115123125783e-17

# %% [markdown]
# ## Floor Division

# %%
# classical division

22/7
# Out:
# 3.142857142857143

# %%
# floor division
# remove the fraction part of the division

22//7
# Out:
# 3
