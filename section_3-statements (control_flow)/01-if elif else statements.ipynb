# %% [markdown]
# ### if statements

# %%
if True:
    print('its True!')
# Out:
# its True!

# %%
if 3>2:
    print("It's True!")
# Out:
# It's True!

# %%
hungry = True

if hungry:
    print("feed me!")
# Out:
# feed me!

# %% [markdown]
# ### if else statements

# %%
hungry=False

if hungry:
    print('feed me')
else:
    print('am not humgry')
    
print(hungry)
# Out:
# am not humgry
# False

# %% [markdown]
# ### if elif else statements

# %%
# branches of if else and elif statements:

loc = 'game'

if loc == 'auto bank':
    print('cars are cool')
    
elif loc == 'bank':
    print('money is cool')
elif loc == 'store':
    print('welcome to the store')
    
else:
    print('i dont know much')
# Out:
# i dont know much
